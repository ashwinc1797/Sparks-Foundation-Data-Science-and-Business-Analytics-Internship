# %% [markdown]
# <center>
#     <img src="https://internship.thesparksfoundation.info/assests/img/logo.png" width="300" alt="thesparksfoundation logo"  />
# </center>

# %% [markdown]
# # GRIP - THE SPARK FOUNDATION
# ## DATA SCIENCE AND BUISNESS ANALYTICS INTERNSHIP

# %% [markdown]
# # Author : Ashwin Chaudhari
#
#
# # Task-3: ‘Exploratory Data Analysis’ -Retail

# %% [markdown]
# ## Objective
# ##### * Perform ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’
#
# ##### * As a business manager, try to find out the weak areas where you can work to make more profit.
# ##### * What all business problems you can derive by exploring the data?

# %% [markdown]
# # 1. Import the required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %% [markdown]
# # 2.  Reading The Data from data source

# %%
mydata = pd.read_csv(r"C:\Users\smart\Downloads\SampleSuperstore.csv")
mydata.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
mydata.tail()
# Out:
#            Ship Mode   Segment        Country  ... Quantity Discount   Profit
# 9989    Second Class  Consumer  United States  ...        3      0.2   4.1028
# 9990  Standard Class  Consumer  United States  ...        2      0.0  15.6332
# 9991  Standard Class  Consumer  United States  ...        2      0.2  19.3932
# 9992  Standard Class  Consumer  United States  ...        4      0.0  13.3200
# 9993    Second Class  Consumer  United States  ...        2      0.0  72.9480
#
# [5 rows x 13 columns]

# %% [markdown]
# # 3 : Analyze the co-relation between the variable

# %%
#Get shape of Data
print('No of records : ',mydata.shape[0])
print('No of variables : ', mydata.shape[1])
# Out:
# No of records :  9994
# No of variables :  13

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
# Let's look at the scatistical description of the Data
mydata.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#Checking the relationship between the veriable with help of correlation function
mydata.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
#Display the relation with the heatmap
plt.figure(figsize=(10,8))
sns.heatmap(mydata.corr(),annot=True,cmap='viridis')

# %%
#checking any missing values in the data
miss_mydata = pd.DataFrame({'Missing_values':mydata.isnull().sum(),"percentage of missing":(mydata.isnull().sum()/mydata.shape[0]*100)})
miss_mydata
# Out:
#               Missing_values  percentage of missing
# Ship Mode                  0                    0.0
# Segment                    0                    0.0
# Country                    0                    0.0
# City                       0                    0.0
# State                      0                    0.0
# Postal Code                0                    0.0
# Region                     0                    0.0
# Category                   0                    0.0
# Sub-Category               0                    0.0
# Sales                      0                    0.0
# Quantity                   0                    0.0
# Discount                   0                    0.0
# Profit                     0                    0.0

# %% [markdown]
# ## In this data-set there is no missing values
# ## Option 1 :
#
# if any data is missing is missing from the data-set . then you have to set it as mean,mode or median, in order to comcomplete it .
# ## Option 2 :
#
# If you have a large amount of data, then you can also delete it .

# %%
#check the data type , count the unique data
unique_mydata = pd.DataFrame({'Unique ':mydata.nunique(),'Dtype':mydata.dtypes})
unique_mydata
# Out:
#               Unique     Dtype
# Ship Mode           4   object
# Segment             3   object
# Country             1   object
# City              531   object
# State              49   object
# Postal Code       631    int64
# Region              4   object
# Category            3   object
# Sub-Category       17   object
# Sales            5825  float64
# Quantity           14    int64
# Discount           12  float64
# Profit           7287  float64

# %% [markdown]
# # 4: Plot the Graph  ,for detail Analysis of Data-set

# %%
#categerical data
cat_mydata = mydata.select_dtypes(include='object')
cat_mydata.head()
# Out:
#         Ship Mode    Segment  ...         Category Sub-Category
# 0    Second Class   Consumer  ...        Furniture    Bookcases
# 1    Second Class   Consumer  ...        Furniture       Chairs
# 2    Second Class  Corporate  ...  Office Supplies       Labels
# 3  Standard Class   Consumer  ...        Furniture       Tables
# 4  Standard Class   Consumer  ...  Office Supplies      Storage
#
# [5 rows x 8 columns]

# %% [markdown]
# ## Visual the cateogrical data

# %%
plt.figure(figsize=(10,8))
sns.set_style(style='whitegrid')
sns.countplot(x=cat_mydata['Segment'],palette='rainbow')
plt.title('Segment',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.set_style(style='whitegrid')
sns.countplot(x=cat_mydata['Ship Mode'],palette='Spectral')
plt.title('Ship Mode',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.set_style(style='ticks')
sns.countplot(x=cat_mydata['State'],palette='Set1')
plt.xticks(rotation=90)
plt.title('State',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.set_style(style='dark')
sns.countplot(x=cat_mydata['Category'],palette='hot')
plt.title('Category',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.set_style(style='darkgrid')
sns.countplot(x=cat_mydata['Sub-Category'],palette='Set1')
plt.title('Sub-Category',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.set_style(style='whitegrid')
sns.countplot(x=cat_mydata['Region'],palette='BuPu')
plt.title('Region',fontsize=20)
plt.show()

# %%
#numerical data
num_mydata = mydata._get_numeric_data()
num_mydata.head()
# Out:
#    Postal Code     Sales  Quantity  Discount    Profit
# 0        42420  261.9600         2      0.00   41.9136
# 1        42420  731.9400         3      0.00  219.5820
# 2        90036   14.6200         2      0.00    6.8714
# 3        33311  957.5775         5      0.45 -383.0310
# 4        33311   22.3680         2      0.20    2.5164

# %%
plt.figure(figsize=(20,8))
sns.displot(num_mydata['Sales'],kde =False)
plt.title('Distribution of Sales data',fontsize=20)
# plt.ylim(20000, 10000)
plt.show()

# %% [markdown]
# This is right-skewed histogram, the mean, median, and mode are all different. In this case, the mode is the highest point of the histogram, whereas the median and mean fall to the right of it (or, visually, the right of the peak). Note that the mean will always be to the right of the median.
#
#
# ![body_skewed_right_left.png](data:image/png;base64,...)

# %%
plt.figure(figsize=(20,8))
sns.displot(num_mydata['Profit'],kde =False)
plt.title('Distribution of Profit data',fontsize=20)
# plt.ylim(20000, 10000)
plt.show()

# %%
#Check the outier's with the help of boxplot
sns.boxplot(num_mydata['Sales'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(num_mydata['Profit'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Check the relationship between the variables to the target
sns.catplot(x='Ship Mode',y='Profit',data=mydata,hue='Category',kind='bar',col='Region',col_wrap=2,height=7,palette='Set2')
plt.show()

# %%
#Top 10 cityes
valu=mydata['City'].value_counts().head(10).values
ind=list(mydata['City'].value_counts().head(10).index)
plt.figure(figsize=(10,8))
plt.pie(valu,labels=ind,pctdistance=0.6,shadow=False,startangle=90)
plt.title('Top 10 Cityes',fontsize=19)
# Out:
# Text(0.5, 1.0, 'Top 10 Cityes')

# %%
#Top 10 cityes
valu=mydata['State'].value_counts().head(10).values
ind=list(mydata['State'].value_counts().head(10).index)
plt.figure(figsize=(10,8))
plt.pie(valu,labels=ind,pctdistance=0.6,explode=[0.06,0.01,0,0,0,0,0,0,0,0],shadow=True,startangle=90)
plt.title('Top 10 States',fontsize=19)
# Out:
# Text(0.5, 1.0, 'Top 10 States')

# %%
#top 20 states which getting high profits
top20_states=mydata[['Profit','State']].nlargest(20,columns=['Profit'])
plt.figure(figsize=(15,7))
sns.barplot(x='State',y='Profit',data=top20_states)
plt.title('Top 20 states Which getting high profits',fontsize=19)
plt.show()

# %%
#top 20 states which getting low profits
top20_states=mydata[['Profit','State']].nsmallest(20,columns=['Profit'])
plt.figure(figsize=(13,7))
sns.barplot(x='Profit',y='State',data=top20_states)
plt.title('Least 20 states Which getting low profits',fontsize=19)
plt.show()

# %%
#top 20 Citys which getting High profits
top20_states=mydata[['Profit','City']].nlargest(20,columns=['Profit'])
plt.figure(figsize=(10,12))
sns.barplot(x='Profit',y='City',data=top20_states)
plt.title('Top 20 Citys Which getting High profits',fontsize=19)
plt.show()

# %%
#top 20 Citys which getting High profits
top20_states=mydata[['Profit','City']].nsmallest(20,columns=['Profit'])
plt.figure(figsize=(10,12))
sns.barplot(x='Profit',y='City',data=top20_states)
plt.title('least 20 Citys Which getting low profits',fontsize=19)
plt.show()

# %%
#Ctegory vs profits
mydata.groupby('Category')['Profit'].sum().plot.bar()
plt.title('Category profits',fontsize=19)
plt.show()

# %%
 #Ctegory vs sales
mydata.groupby('Category')['Sales'].sum().plot.bar()
plt.title('Category Sales',fontsize=19)
plt.show()

# %%
#Relation ship between the sales and profit
sns.scatterplot(mydata['Sales'],mydata['Profit'],markers='o',color='r')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Display the amount of quantity getting higher profits
sns.catplot(x='Quantity',y='Profit',data=mydata,kind='bar',height=7)

# %%
#Feature engineering
#The columns such as 'Country','Postal code' doesn't require
df_new=mydata.copy()
df_new.drop(columns=['Country','Postal Code'],axis=1,inplace=True)

# %%
#Encode the categorical data in to numerical data to better understanding the data during the model building
from sklearn.preprocessing import LabelEncoder
lc=LabelEncoder()
df_new['Ship Mode']=lc.fit_transform(df_new['Ship Mode'])
df_new['Segment']=lc.fit_transform(df_new['Segment'])
df_new['City']=lc.fit_transform(df_new['City'])
df_new['State']=lc.fit_transform(df_new['State'])
df_new['Region']=lc.fit_transform(df_new['Region'])
df_new['Category']=lc.fit_transform(df_new['Category'])
df_new['Sub-Category']=lc.fit_transform(df_new['Sub-Category'])

# %%
#After transformations of categorical data in to numerical data
df_new.head()
# Out:
#    Ship Mode  Segment  City  State  ...     Sales  Quantity  Discount    Profit
# 0          2        0   194     15  ...  261.9600         2      0.00   41.9136
# 1          2        0   194     15  ...  731.9400         3      0.00  219.5820
# 2          2        1   266      3  ...   14.6200         2      0.00    6.8714
# 3          3        0   153      8  ...  957.5775         5      0.45 -383.0310
# 4          3        0   153      8  ...   22.3680         2      0.20    2.5164
#
# [5 rows x 11 columns]

# %%
#feature transformation
df_new['Sales']=np.log(df_new['Sales'])

# %%
#Split the data in to x and y
x=df_new.drop(['Profit'],1)
y=df_new['Profit']

# %%
#splitting the data in to train and test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
#Model building
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

# %%
algos = [LinearRegression(),RandomForestRegressor(),Ridge(), Lasso(),
          KNeighborsRegressor(), DecisionTreeRegressor(),SVR()]

names = ['Linear Regression','RandomForestRegressor', 'Ridge Regression', 'Lasso Regression',
         'K Neighbors Regressor', 'Decision Tree Regressor','SVR']

rmse_list = []

# %%
for name in algos:
    model = name
    model.fit(x_train,y_train)
    train_score= model.score(x_train,y_train)
    test_Score=model.score(x_test,y_test)
    rmse_list.append([train_score,test_Score])

# %%
#Get the evaluation performnace on the data
evaluat=pd.DataFrame({'Model':names,'Train score & Test score':rmse_list})
evaluat
# Out:
#                      Model                        Train score & Test score
# 0        Linear Regression      [0.09170607649686692, 0.08198695247863352]
# 1    RandomForestRegressor        [0.9616342704944507, 0.8057782770534431]
# 2         Ridge Regression      [0.09170564399755554, 0.08195317970591942]
# 3         Lasso Regression      [0.09102014551518887, 0.07990490703565523]
# 4    K Neighbors Regressor      [0.45280119596688223, 0.03505712059895005]
# 5  Decision Tree Regressor        [0.9999889910585669, 0.7840168476554464]
# 6                      SVR  [-0.006187502567199354, -0.006965253278382155]

# %% [markdown]
# from the above performances metrics RandomForestRegressor performs well in our usecase as compared to the other algorithem's, we may select the algorithem for further predictions on the new data.
#
# # 5. Conclusion
#
# We can see that the sales of the 'Furniture','Technology','Office supllies' is equaly but when the profit comes in to picture the 'Furniture' category is comparitivly generates very low profits as compared to the other categories , we need to focus it on more to get the profits equally to of them.
#
# Also the cities which getting low profits such as 'Lancaster','Berlington','San antonio','Chicago' etc.
#
# ## What all business problems you can derive by exploring the data?
#
# If i increase the sales in those categories, how much i can get more profits in various cities and states.
#
# Which Category is more likely to be sale.
#
# What type of category is people more intrested in those cities and states.
#
# How many profits are generating in each region, also which type of product is more likely to be sale.
#
# Will sales increase the profits eqauliy or not.
#
# How much gain or loss.
#
#
# If the quantity increases, automatically the profit increases or not.
#
# In which we need to focus more to generate the profits and sales.
#
# Which type of shipmode is people likely to be interest.
#
# Based on the Discount, how much the people will be interested to purchase.
#
# Is discount helps us to generate more profits.
#
# Is Discount helps to increase the sales.
#
# If we Increase the Discount's on those category , what type of category is more likely to be sold in which areas.
